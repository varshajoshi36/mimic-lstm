# %%
#Generates 3D numpy array from mimic iii data.  One hot encoded.  Shards into num_shards numpy arrays.

import pandas as pd
import math
import numpy as np
import sys
from datetime import datetime

class Feature(object):
    def __init__(self, path="~/mimic3/data_full/"):
        self.path = path
        
    def get_admission(self):
        admission_df = pd.read_csv(self.path+'ADMISSIONS.csv', usecols=['SUBJECT_ID','HADM_ID','ADMITTIME'])
        
        #Sort by HADM_ID
        admission_df = admission_df.set_index('HADM_ID', drop = False)
        admission_df.sort_index(inplace=True)
        
        #Take first eigth of admissions (Memory constraint)
#         admission_df = admission_df.iloc[0:round(len(admission_df)/8)]
        return admission_df
    
    #loads the chartevents file
    
    def get_chartevents(self, items, adm):
        c_df = pd.read_csv(self.path+'CHARTEVENTS.csv', usecols=['HADM_ID','ITEMID','CHARTTIME','VALUENUM'])
        #takes rows for patients that appear in admissions,
        c_df = c_df[c_df['HADM_ID'].isin(adm['HADM_ID'])]
        #take measurement values that are not null.
        c_df = c_df[c_df['VALUENUM'].notnull()]
        #take rows with desired item IDs
        c_df = c_df[c_df.ITEMID.isin([x for v in items.values() for x in v])]
        #Normalize each measurent values to mean zero and std dev 1 accross each item ID
        for item_n in items.keys():
            for itid in items[item_n]:
                c_df.loc[c_df['ITEMID'] == itid,'VALUENUM'] = (c_df.loc[c_df['ITEMID']==itid, 'VALUENUM'] 
                                                           - c_df.loc[c_df['ITEMID']==itid, 'VALUENUM'].mean())/c_df.loc[c_df['ITEMID'] == itid,'VALUENUM'].std()
        return c_df 
    
    #Defines the item IDs that will be used in the dataset
    def get_items(self):
        HR = [220045, 211] #['Heart Rate', 'Heart Rate']
        #BPm = [220181 , 52, 456, 220052] #['Non Invasive Blood Pressure mean', 'Arterial BP Mean','NBP Mean', 'Arterial Blood Pressure mean']
        BP_S = [51]#220179, , 220050]  #['Non Invasive Blood Pressure systolic', 'Arterial BP [Systolic]', 455, 'NBP [Systolic]', 'Arterial Blood Pressure systolic']
        BP_D = [8368]#220180, , 220051] #, ['Non Invasive Blood Pressure diastolic', 'Arterial BP [Diastolic]', 8441'NBP [Diastolic]', 'Arterial Blood Pressure diastolic'] 
        CAP_Refill = [] 
        Glucose = [807]#, 225664, 811, 227015] # ['Fingerstick Glucose', 'Glucose finger stick','Glucose (70-105)'] 
        pH = [227037] 
        Temp = [223761]#, 678, 679, 227054]  #['Temperature Fahrenheit', 'Temperature F', 'Temperature F (calc)']
        UrineScore = [227059] 
        O2_Sat = [220277]#, 646, 227035] #['O2 saturation pulseoxymetry', 'SpO2'] 
        RespiratoryRate = [220210]#, 618, 615] #['Respiratory Rate', 'Respiratory Rate','Resp Rate (Total)']
        GCS = [198] #['GCS Total']
        FiO2 = [223835]#, 1040] #['Inspired O2 Fraction (%)']
        ETCO2 = [1817]
        return {
            'HR': HR,
            'BP_S': BP_S,
            'BP_D': BP_D,
            'CAP_Refill': CAP_Refill,
            'Glucose': Glucose,
            'pH': pH,
            'Temp': Temp,
            'UrineScore': UrineScore,
            'O2_Sat': O2_Sat,
            'RespiratoryRate': RespiratoryRate,
            'GCS': GCS,
            'FiO2': FiO2,
            'ETCO2': ETCO2
        }
#     def get_it_mean_std(self,items, ce):
#         valms = { item_n : ce[ce.ITEMID.isin(items[item_n])].VALUENUM.mean() for item_n in sorted(items.keys())}
#         valst = { item_n : ce[ce.ITEMID.isin(items[item_n])].VALUENUM.std() for item_n in sorted(items.keys())}
#         return (valms, valst)
        
    def get_relative_time(self, admit_time, chart_time):
        """
        admit_time, chart_time str
        :return value in hours
        """
        
        # Accepts strings in "2144-07-24 09:00:00" format and returns difference in seconds
        adm_time = datetime.strptime(admit_time, '%Y-%m-%d %H:%M:%S')
        char_time = datetime.strptime(chart_time, '%Y-%m-%d %H:%M:%S')
        del_time = char_time - adm_time
        rel_time = del_time.days*86400 + del_time.seconds
        return rel_time/3600
    

    def get_relative_time_per_admid2(self, df, admit_time):
        """
        :param df: chartevent df for particular HADM_ID
        :param admit_time: str
        :return tuple (new df with extra column, number of measurements)
        """
        rlt = []
        numMeas = 0
        for cTime in df['CHARTTIME']:
            temp = self.get_relative_time(admit_time, cTime)
            #set chart times that are before admittime to 0.
            if temp > 0:
                rlt.append(temp)
            else:
                rlt.append(0)
            numMeas += 1    

        df['RELTIME'] = rlt
        return (df, numMeas)
    
    def get_max_time_per_admid(self, df, admit_time):
        """
        :param df: chartevent df for particular HADM_ID
        :param admit_time: str
        :return tuple (new df with extra column, max time patient was monitored)
        """
        rlt = []
        max_time = 0
        for cTime in df['CHARTTIME']:
            temp = self.get_relative_time(admit_time, cTime)
            rlt.append(temp)
            if (temp > max_time):
                max_time = temp
        
        
        return max_time


    def get_max_time(self, chartevents_df, admission_df):
        max_t = 0
        for idx, admission in admission_df.iterrows():
            max_time = self.get_max_time_per_admid(
                chartevents_df[chartevents_df['HADM_ID'] == admission['HADM_ID']],
                admission['ADMITTIME'])# max_time is in hours
            if(max_time > max_t):
                max_t = max_time
        return int(max_t)
        
    def printl(self, string):
        print(string)
        sys.stdout.flush()
        
    def OH_F(self, ITID, itemsd):
        oh_v = np.zeros(len(itemsd))
        iidx = 0
        for item_name in sorted(itemsd.keys()):
            if ITID in itemsd[item_name]:
                oh_v[iidx] = 1
                th_item_name = item_name
            iidx += 1
        return (oh_v, th_item_name)
    
    def get_OH(self, admission_df,chartevents_df,items):
        # Generates and saves a numpy array consisting of measurements for all patients in admission_df
        
        #(valms, valst) = self.get_it_mean_std(items, chartevents_df)
        
        #Get rows for patients in admission_df
        chartevents_df = chartevents_df[chartevents_df['HADM_ID'].isin(admission_df['HADM_ID'])]
        
        self.printl('getting dimensions')
        #Find dimension of array (numPat x num_meas x feature length)
        numPat = len(admission_df.groupby('HADM_ID').size())
        maxNumMeas = chartevents_df.groupby('HADM_ID').size().max()
        feaLen = len(items)+2
        
        self.printl('making array')
        #Generate array of zeros that will be filled below
        features = np.zeros(shape=(numPat, maxNumMeas, feaLen))
        z = np.zeros(shape=(numPat))
        
        pat_idx = 0
        
        #For each patient in admission_df save the measurements to array
        for sbj_id, admission in admission_df.iterrows():
            
            cnt = 0 #indexes measurements
            
            self.printl(str(admission['HADM_ID']) + ' started')
            
            #Get (dataframe for a specific patient with Reltime column, number of measurements)
            (chartevents_perAdm_df, numMeas) = self.get_relative_time_per_admid2(
                    chartevents_df[chartevents_df['HADM_ID'] == admission['HADM_ID']],
                    admission['ADMITTIME'])
            
            #Save the sequence length to z
            z[pat_idx] = numMeas
            
#             #Generate 2D array for measurements of this patient.
#             feature_patient = np.zeros(shape=(features.shape[1], features.shape[2]))
            
            #Sort by time
            chartevents_perAdm_df = chartevents_perAdm_df.set_index('RELTIME', drop = False)
            chartevents_perAdm_df.sort_index(inplace=True)
            
            #for each row in chartevents create a row in 3D array 
            for c_idx, row in chartevents_perAdm_df.iterrows():
                ITID = row['ITEMID']
                #Generate one hot encoding for feature type.
                (oh_v, it_n) = self.OH_F(ITID, items)
                #assign corresponding row in array to the one hot vector, the time, and the value of measurement.
                features[pat_idx, cnt] = np.append(oh_v, [row['RELTIME'], row['VALUENUM']])
                cnt += 1
                
            pat_idx +=1
        return features, z
    
    def get_shards(self, num_shards):
        #Creates num_shards numpy arrays
        items = self.get_items()
        
        self.printl('getting admissions')
        adm_df = self.get_admission()
        
        self.printl('getting chart events')
        c_df = self.get_chartevents(items,adm_df)
        
        #set starting indices
        s_len = int(len(adm_df)/num_shards)
        st_idx = 0
          
            
        for i in np.arange(num_shards):
            #generate arrays for indices
            x,z = self.get_OH(adm_df[st_idx:st_idx+s_len],c_df,items)
            #save arrays
            np.save("xC"+str(i),x)
            np.save("zC"+str(i),z) 
            #roll arrays forward
            st_idx += s_len
#             np.roll(adm_df,s_len)

# %%
feature = Feature()
feature.get_shards(100)

print("done")
# Out:
# getting admissions
# getting chart events
# getting dimensions
# making array
# 100001 started
# 100003 started
# 100006 started
# 100007 started
# /soe/dcjenkin/workspace/venv/lib/python3.4/site-packages/ipykernel/__main__.py:108: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 100009 started
# 100010 started
# 100011 started
# 100012 started
# 100014 started
# 100016 started
# 100017 started
# 100018 started
# 100019 started
# 100020 started
# 100021 started
# 100023 started
# 100024 started
# 100025 started
# 100028 started
# 100029 started
# 100030 started
# 100031 started
# 100033 started
# 100034 started
# 100035 started
# 100036 started
# 100037 started
# 100038 started
# 100039 started
# 100040 started
# 100041 started
# 100044 started
# 100045 started
# 100046 started
# 100047 started
# 100050 started
# 100052 started
# 100053 started
# 100055 started
# 100058 started
# 100059 started
# 100060 started
# 100061 started
# 100062 started
# 100063 started
# 100065 started
# 100066 started
# 100068 started
# 100069 started
# 100071 started
# 100072 started
# 100074 started
# 100075 started
# 100077 started
# 100078 started
# 100079 started
# 100081 started
# 100085 started
# 100087 started
# 100088 started
# 100091 started
# 100094 started
# 100095 started
# 100096 started
# 100098 started
# 100099 started
# 100102 started
# 100103 started
# 100104 started
# 100106 started
# 100108 started
# 100109 started
# 100112 started
# 100113 started
# 100114 started
# 100116 started
# 100117 started
# 100118 started
# 100119 started
# 100120 started
# 100121 started
# 100124 started
# 100125 started
# 100126 started
# 100130 started
# 100131 started
# 100132 started
# 100133 started
# 100135 started
# 100136 started
# 100137 started
# 100138 started
# 100139 started
# 100140 started
# 100141 started
# 100142 started
# 100143 started
# 100146 started
# 100147 started
# 100150 started
# 100151 started
# 100153 started
# 100154 started
# 100156 started
# 100159 started
# 100160 started
# 100161 started
# 100162 started
# 100163 started
# 100165 started
# 100166 started
# 100167 started
# 100168 started
# 100173 started
# 100174 started
# 100177 started
# 100179 started
# 100182 started
# 100184 started
# 100185 started
# 100186 started
# 100187 started
# 100188 started
# 100191 started
# 100192 started
# 100195 started
# 100197 started
# 100199 started
# 100201 started
# 100202 started
# 100203 started
# 100206 started
# 100208 started
# 100209 started
# 100210 started
# 100211 started
# 100213 started
# 100215 started
# 100217 started
# 100220 started
# 100223 started
# 100224 started
# 100225 started
# 100227 started
# 100229 started
# 100230 started
# 100232 started
# 100234 started
# 100237 started
# 100238 started
# 100240 started
# 100241 started
# 100242 started
# 100247 started
# 100248 started
# 100249 started
# 100250 started
# 100252 started
# 100253 started
# 100257 started
# 100260 started
# 100261 started
# 100262 started
# 100263 started
# 100264 started
# 100265 started
# 100267 started
# 100268 started
# 100269 started
# 100270 started
# 100271 started
# 100277 started
# 100281 started
# 100282 started
# 100283 started
# 100284 started
# 100286 started
# 100289 started
# 100290 started
# 100292 started
# 100294 started
# 100295 started
# 100297 started
# 100298 started
# 100300 started
# 100301 started
# 100302 started
# 100303 started
# 100304 started
# 100307 started
# 100309 started
# 100311 started
# 100312 started
# 100313 started
# 100315 started
# 100318 started
# 100319 started
# 100320 started
# 100321 started
# 100322 started
# 100324 started
# 100325 started
# 100326 started
# 100328 started
# 100329 started
# 100335 started
# 100336 started
# 100337 started
# 100338 started
# 100339 started
# 100341 started
# 100342 started
# 100343 started
# 100345 started
# 100346 started
# 100347 started
# 100349 started
# 100350 started
# 100352 started
# 100355 started
# 100357 started
# 100359 started
# 100360 started
# 100361 started
# 100364 started
# 100367 started
# 100372 started
# 100373 started
# 100374 started
# 100375 started
# 100376 started
# 100378 started
# 100379 started
# 100380 started
# 100381 started
# 100383 started
# 100385 started
# 100386 started
# 100387 started
# 100388 started
# 100391 started
# 100392 started
# 100394 started
# 100395 started
# 100398 started
# 100399 started
# 100401 started
# 100402 started
# 100403 started
# 100406 started
# 100408 started
# 100410 started
# 100415 started
# 100416 started
# 100417 started
# 100419 started
# 100421 started
# 100422 started
# 100423 started
# 100426 started
# 100427 started
# 100428 started
# 100429 started
# 100431 started
# 100432 started
# 100434 started
# 100438 started
# 100439 started
# 100440 started
# 100442 started
# 100445 started
# 100446 started
# 100448 started
# 100449 started
# 100450 started
# 100452 started
# 100453 started
# 100454 started
# 100455 started
# 100456 started
# 100457 started
# 100458 started
# 100459 started
# 100460 started
# 100463 started
# 100465 started
# 100467 started
# 100468 started
# 100469 started
# 100470 started
# 100473 started
# 100474 started
# 100475 started
# 100477 started
# 100481 started
# 100483 started
# 100485 started
# 100486 started
# 100487 started
# 100488 started
# 100489 started
# 100490 started
# 100492 started
# 100493 started
# 100494 started
# 100496 started
# 100498 started
# 100499 started
# 100504 started
# 100508 started
# 100509 started
# 100510 started
# 100511 started
# 100513 started
# 100514 started
# 100517 started
# 100522 started
# 100524 started
# 100525 started
# 100526 started
# 100529 started
# 100530 started
# 100532 started
# 100535 started
# 100536 started
# 100538 started
# 100539 started
# 100543 started
# 100545 started
# 100547 started
# 100548 started
# 100549 started
# 100553 started
# 100556 started
# 100557 started
# 100559 started
# 100560 started
# 100561 started
# 100562 started
# 100563 started
# 100564 started
# 100566 started
# 100569 started
# 100570 started
# 100571 started
# 100572 started
# 100575 started
# 100576 started
# 100579 started
# 100580 started
# 100581 started
# 100583 started
# 100584 started
# 100585 started
# 100586 started
# 100589 started
# 100590 started
# 100591 started
# 100594 started
# 100597 started
# 100598 started
# 100599 started
# 100603 started
# 100605 started
# 100606 started
# 100608 started
# 100610 started
# 100612 started
# 100613 started
# 100615 started
# 100616 started
# 100617 started
# 100618 started
# 100619 started
# 100620 started
# 100621 started
# 100622 started
# 100625 started
# 100626 started
# 100635 started
# 100636 started
# 100637 started
# 100638 started
# 100639 started
# 100640 started
# 100641 started
# 100642 started
# 100643 started
# 100647 started
# 100653 started
# 100654 started
# 100656 started
# 100657 started
# 100658 started
# 100659 started
# 100660 started
# 100661 started
# 100662 started
# 100663 started
# 100664 started
# 100665 started
# 100666 started
# 100672 started
# 100674 started
# 100676 started
# 100677 started
# 100678 started
# 100680 started
# 100681 started
# 100683 started
# 100684 started
# 100685 started
# 100686 started
# 100687 started
# 100689 started
# 100694 started
# 100696 started
# 100697 started
# 100698 started
# 100699 started
# 100701 started
# 100704 started
# 100705 started
# 100709 started
# 100710 started
# 100711 started
# 100712 started
# 100713 started
# 100715 started
# 100718 started
# 100719 started
# 100724 started
# 100725 started
# 100726 started
# 100728 started
# 100729 started
# 100730 started
# 100732 started
# 100733 started
# 100735 started
# 100736 started
# 100738 started
# 100740 started
# 100742 started
# 100744 started
# 100746 started
# 100747 started
# 100748 started
# 100749 started
# 100751 started
# 100752 started
# 100753 started
# 100754 started
# 100755 started
# 100756 started
# 100757 started
# 100758 started
# 100759 started
# 100761 started
# 100763 started
# 100764 started
# 100765 started
# 100769 started
# 100770 started
# 100771 started
# 100774 started
# 100775 started
# 100776 started
# 100777 started
# 100778 started
# 100779 started
# 100781 started
# 100783 started
# 100784 started
# 100786 started
# 100787 started
# 100788 started
# 100789 started
# 100791 started
# 100792 started
# 100793 started
# 100794 started
# 100795 started
# 100797 started
# 100799 started
# 100803 started
# 100804 started
# 100805 started
# 100806 started
# 100808 started
# 100809 started
# 100810 started
# 100811 started
# 100812 started
# 100813 started
# 100814 started
# 100815 started
# 100816 started
# 100817 started
# 100818 started
# 100820 started
# 100824 started
# 100825 started
# 100826 started
# 100827 started
# 100830 started
# 100831 started
# 100834 started
# 100836 started
# 100837 started
# 100838 started
# 100841 started
# 100842 started
# 100845 started
# 100846 started
# 100847 started
# 100848 started
# 100849 started
# 100851 started
# 100852 started
# 100853 started
# 100855 started
# 100856 started
# 100859 started
# 100861 started
# 100863 started
# 100866 started
# 100869 started
# 100870 started
# 100871 started
# 100872 started
# 100873 started
# 100877 started
# 100881 started
# 100883 started
# 100884 started
# 100887 started
# 100888 started
# 100889 started
# 100890 started
# 100891 started
# 100893 started
# 100897 started
# 100899 started
# 100900 started
# 100901 started
# 100902 started
# 100907 started
# 100908 started
# 100909 started
# 100910 started
# 100912 started
# 100913 started
# 100914 started
# 100915 started
# 100916 started
# 100918 started
# 100919 started
# 100921 started
# 100922 started
# 100924 started
# 100926 started
# 100927 started
# 100929 started
# 100930 started
# 100931 started
# 100932 started
# 100933 started
# 100934 started
# 100935 started
# 100937 started
# 100938 started
# 100940 started
# 100941 started
# 100942 started
# 100943 started
# 100945 started
# 100946 started
# 100947 started
# 100949 started
# 100950 started
# 100952 started
# 100954 started
# 100956 started
# 100957 started
# 100958 started
# 100960 started
# 100961 started
# 100962 started
# getting dimensions
# making array
# 100966 started
# 100969 started
# 100973 started
# 100974 started
# 100975 started
# 100976 started
# 100977 started
# 100978 started
# 100979 started
# 100980 started
# 100981 started
# 100982 started
# 100983 started
# 100984 started
# 100985 started
# 100988 started
# 100989 started
# 100990 started
# 100991 started
# 100993 started
# 100994 started
# 100995 started
# 100998 started
# 100999 started
# 101001 started
# 101002 started
# 101003 started
# 101005 started
# 101006 started
# 101007 started
# 101008 started
# 101009 started
# 101011 started
# 101013 started
# 101014 started
# 101015 started
# 101017 started
# 101018 started
# 101019 started
# 101020 started
# 101024 started
# 101025 started
# 101026 started
# 101027 started
# 101028 started
# 101029 started
# 101031 started
# 101033 started
# 101034 started
# 101037 started
# 101038 started
# 101039 started
# 101043 started
# 101045 started
# 101046 started
# 101047 started
# 101049 started
# 101050 started
# 101051 started
# 101052 started
# 101053 started
# 101054 started
# 101056 started
# 101057 started
# 101061 started
# 101062 started
# 101063 started
# 101065 started
# 101067 started
# 101068 started
# 101071 started
# 101072 started
# 101073 started
# 101074 started
# 101076 started
# 101077 started
# 101078 started
# 101080 started
# 101081 started
# 101083 started
# 101085 started
# 101086 started
# 101087 started
# 101089 started
# 101090 started
# 101091 started
# 101092 started
# 101094 started
# 101095 started
# 101096 started
# 101098 started
# 101099 started
# 101100 started
# 101101 started
# 101102 started
# 101104 started
# 101106 started
# 101109 started
# 101110 started
# 101113 started
# 101114 started
# 101116 started
# 101117 started
# 101118 started
# 101119 started
# 101121 started
# 101124 started
# 101125 started
# 101126 started
# 101128 started
# 101130 started
# 101131 started
# 101133 started
# 101136 started
# 101138 started
# 101142 started
# 101143 started
# 101145 started
# 101146 started
# 101148 started
# 101151 started
# 101152 started
# 101153 started
# 101157 started
# 101160 started
# 101161 started
# 101162 started
# 101165 started
# 101168 started
# 101169 started
# 101170 started
# 101171 started
# 101172 started
# 101173 started
# 101180 started
# 101182 started
# 101184 started
# 101186 started
# 101188 started
# 101189 started
# 101193 started
# 101194 started
# 101195 started
# 101197 started
# 101198 started
# 101199 started
# 101201 started
# 101204 started
# 101206 started
# 101207 started
# 101208 started
# 101209 started
# 101211 started
# 101212 started
# 101215 started
# 101216 started
# 101217 started
# 101220 started
# 101222 started
# 101223 started
# 101226 started
# 101227 started
# 101229 started
# 101232 started
# 101233 started
# 101237 started
# 101239 started
# 101240 started
# 101241 started
# 101242 started
# 101243 started
# 101244 started
# 101245 started
# 101246 started
# 101249 started
# 101250 started
# 101251 started
# 101254 started
# 101256 started
# 101257 started
# 101259 started
# 101261 started
# 101263 started
# 101264 started
# 101265 started
# 101266 started
# 101268 started
# 101269 started
# 101271 started
# 101272 started
# 101274 started
# 101276 started
# 101277 started
# 101278 started
# 101280 started
# 101281 started
# 101286 started
# 101289 started
# 101291 started
# 101295 started
# 101296 started
# 101297 started
# 101299 started
# 101302 started
# 101303 started
# 101304 started
# 101305 started
# 101306 started
# 101307 started
# 101308 started
# 101309 started
# 101310 started
# 101311 started
# 101315 started
# 101316 started
# 101317 started
# 101318 started
# 101322 started
# 101323 started
# 101324 started
# 101325 started
# 101326 started
# 101328 started
# 101329 started
# 101330 started
# 101331 started
# 101332 started
# 101333 started
# 101334 started
# 101335 started
# 101338 started
# 101339 started
# 101340 started
# 101341 started
# 101342 started
# 101343 started
# 101344 started
# 101348 started
# 101350 started
# 101351 started
# 101352 started
# 101353 started
# 101357 started
# 101358 started
# 101359 started
# 101360 started
# 101361 started
# 101363 started
# 101367 started
# 101368 started
# 101371 started
# 101372 started
# 101373 started
# 101374 started
# 101379 started
# 101380 started
# 101381 started
# 101382 started
# 101384 started
# 101386 started
# 101387 started
# 101388 started
# 101391 started
# 101394 started
# 101397 started
# 101399 started
# 101400 started
# 101401 started
# 101404 started
# 101405 started
# 101406 started
# 101408 started
# 101409 started
# 101410 started
# 101411 started
# 101414 started
# 101420 started
# 101422 started
# 101423 started
# 101424 started
# 101425 started
# 101427 started
# 101428 started
# 101430 started
# 101431 started
# 101432 started
# 101433 started
# 101435 started
# 101437 started
# 101439 started
# 101440 started
# 101441 started
# 101442 started
# 101443 started
# 101444 started
# 101445 started
# 101448 started
# 101449 started
# 101451 started
# 101453 started
# 101457 started
# 101460 started
# 101462 started
# 101463 started
# 101466 started
# 101468 started
# 101471 started
# 101477 started
# 101478 started
# 101480 started
# 101481 started
# 101482 started
# 101483 started
# 101484 started
# 101485 started
# 101487 started
# 101490 started
# 101492 started
# 101496 started
# 101499 started
# 101501 started
# 101503 started
# 101504 started
# 101509 started
# 101511 started
# 101512 started
# 101513 started
# 101514 started
# 101515 started
# 101516 started
# 101517 started
# 101521 started
# 101523 started
# 101524 started
# 101525 started
# 101528 started
# 101533 started
# 101534 started
# 101535 started
# 101536 started
# 101537 started
# 101540 started
# 101542 started
# 101543 started
# 101544 started
# 101545 started
# 101546 started
# 101547 started
# 101549 started
# 101552 started
# 101553 started
# 101554 started
# 101555 started
# 101556 started
# 101558 started
# 101560 started
# 101562 started
# 101564 started
# 101566 started
# 101567 started
# 101568 started
# 101569 started
# 101573 started
# 101578 started
# 101579 started
# 101580 started
# 101581 started
# 101584 started
# 101585 started
# 101586 started
# 101587 started
# 101588 started
# 101589 started
# 101590 started
# 101593 started
# 101594 started
# 101596 started
# 101598 started
# 101600 started
# 101601 started
# 101603 started
# 101605 started
# 101608 started
# 101611 started
# 101612 started
# 101614 started
# 101616 started
# 101619 started
# 101621 started
# 101622 started
# 101623 started
# 101624 started
# 101625 started
# 101627 started
# 101629 started
# 101630 started
# 101631 started
# 101633 started
# 101636 started
# 101637 started
# 101640 started
# 101641 started
# 101642 started
# 101643 started
# 101644 started
# 101645 started
# 101648 started
# 101649 started
# 101650 started
# 101651 started
# 101652 started
# 101653 started
# 101656 started
# 101657 started
# 101658 started
# 101659 started
# 101661 started
# 101662 started
# 101663 started
# 101664 started
# 101665 started
# 101667 started
# 101668 started
# 101671 started
# 101674 started
# 101675 started
# 101678 started
# 101679 started
# 101680 started
# 101681 started
# 101683 started
# 101685 started
# 101687 started
# 101689 started
# 101690 started
# 101695 started
# 101697 started
# 101698 started
# 101700 started
# 101701 started
# 101702 started
# 101703 started
# 101704 started
# 101705 started
# 101706 started
# 101707 started
# 101708 started
# 101710 started
# 101711 started
# 101713 started
# 101715 started
# 101718 started
# 101719 started
# 101721 started
# 101722 started
# 101723 started
# 101726 started
# 101727 started
# 101728 started
# 101729 started
# 101731 started
# 101732 started
# 101733 started
# 101735 started
# 101737 started
# 101738 started
# 101739 started
# 101740 started
# 101741 started
# 101742 started
# 101743 started
# 101744 started
# 101746 started
# 101747 started
# 101748 started
# 101749 started
# 101751 started
# 101752 started
# 101753 started
# 101754 started
# 101756 started
# 101757 started
# 101759 started
# 101761 started
# 101762 started
# 101763 started
# 101764 started
# 101767 started
# 101768 started
# 101770 started
# 101776 started
# 101778 started
# 101779 started
# 101785 started
# 101786 started
# 101787 started
# 101789 started
# 101791 started
# 101793 started
# 101794 started
# 101795 started
# 101797 started
# 101802 started
# 101803 started
# 101805 started
# 101806 started
# 101808 started
# 101809 started
# 101810 started
# 101812 started
# 101813 started
# 101815 started
# 101816 started
# 101817 started
# 101818 started
# 101819 started
# 101820 started
# 101821 started
# 101823 started
# 101824 started
# 101826 started
# 101828 started
# 101829 started
# 101831 started
# 101833 started
# 101838 started
# 101840 started
# 101841 started
# 101847 started
# 101850 started
# 101851 started
# 101852 started
# 101853 started
# 101857 started
# 101858 started
# 101859 started
# 101864 started
# 101866 started
# 101868 started
# 101869 started
# 101870 started
# 101872 started
# 101873 started
# 101875 started
# 101876 started
# 101878 started
# 101882 started
# 101883 started
# 101885 started
# 101886 started
# 101891 started
# 101893 started
# 101896 started
# 101897 started
# 101899 started
# 101901 started
# 101902 started
# 101903 started
# 101904 started
# 101905 started
# 101906 started
# 101907 started
# 101908 started
# 101912 started
# 101913 started
# 101914 started
# 101915 started
# 101916 started
# 101919 started
# 101920 started
# 101921 started
# 101922 started
# 101923 started
# 101924 started
# 101925 started
# 101931 started
# 101933 started
# 101934 started
# 101935 started
# 101936 started
# 101939 started
# 101940 started
# 101944 started
# 101945 started
# 101946 started
# 101947 started
# 101948 started
# 101950 started
# 101952 started
# getting dimensions
# making array
# 101953 started
# 101955 started
# 101956 started
# 101959 started
# 101960 started
# 101961 started
# 101962 started
# 101964 started
# 101966 started
# 101967 started
# 101969 started
# 101973 started
# 101974 started
# 101975 started
# 101976 started
# 101977 started
# 101978 started
# 101979 started
# 101982 started
# 101983 started
# 101984 started
# 101985 started
# 104218 started
# 104220 started
# 104222 started
# 104223 started
# 104224 started
# 104225 started
# 104227 started
# 104229 started
# 104231 started
# 104234 started
# 104235 started
# 104236 started
# 104237 started
# 104239 started
# 104241 started
# 104242 started
# 104243 started
# 104246 started
# 104247 started
# 104248 started
# 104250 started
# 104252 started
# 104254 started
# 104257 started
# 104259 started
# 104260 started
# 104262 started
# 104263 started
# 104264 started
# 104265 started
# 104268 started
# 104270 started
# 104271 started
# 104276 started
# 104277 started
# 104280 started
# 104283 started
# 104285 started
# 104286 started
# 104287 started
# 104288 started
# 104289 started
# 104290 started
# 104292 started
# 104293 started
# 104294 started
# 104297 started
# 104298 started
# 104301 started
# 104303 started
# 104305 started
# 104311 started
# 104312 started
# 104313 started
# 104315 started
# 104316 started
# 104319 started
# 104320 started
# 104322 started
# 104323 started
# 104324 started
# 104325 started
# 104326 started
# 104328 started
# 104329 started
# 104332 started
# 104333 started
# 104335 started
# 104336 started
# 104337 started
# 104340 started
# 104343 started
# 104347 started
# 104348 started
# 104350 started
# 104351 started
# 104352 started
# 104354 started
# 104356 started
# 104360 started
# 104361 started
# 104363 started
# 104364 started
# 104366 started
# 104367 started
# 104371 started
# 104372 started
# 104373 started
# 104374 started
# 104377 started
# 104379 started
# 104380 started
# 104381 started
# 104383 started
# 104388 started
# 104390 started
# 104395 started
# 104396 started
# 104397 started
# 104398 started
# 104399 started
# 104400 started
# 104404 started
# 104405 started
# 104406 started
# 104407 started
# 104408 started
# 104409 started
# 104410 started
# 104412 started
# 104414 started
# 104415 started
# 104416 started
# 104418 started
# 104422 started
# 104424 started
# 104427 started
# 104430 started
# 104431 started
# 104432 started
# 104433 started
# 104434 started
# 104435 started
# 104436 started
# 104437 started
# 104438 started
# 104441 started
# 104443 started
# 104445 started
# 104446 started
# 104447 started
# 104448 started
# 104449 started
# 104450 started
# 104451 started
# 104454 started
# 104456 started
# 104457 started
# 104462 started
# 104463 started
# 104464 started
# 104465 started
# 104466 started
# 104467 started
# 104468 started
# 104470 started
# 104471 started
# 104474 started
# 104475 started
# 104477 started
# 104481 started
# 104482 started
# 104484 started
# 104485 started
# 104486 started
# 104487 started
# 104490 started
# 104491 started
# 104495 started
# 104501 started
# 104502 started
# 104503 started
# 104504 started
# 104505 started
# 104508 started
# 104511 started
# 104512 started
# 104515 started
# 104516 started
# 104518 started
# 104519 started
# 104520 started
# 104521 started
# 104524 started
# 104525 started
# 104530 started
# 104533 started
# 104534 started
# 104535 started
# 104536 started
# 104538 started
# 104539 started
# 104540 started
# 104541 started
# 104543 started
# 104545 started
# 104546 started
# 104549 started
# 104551 started
# 104552 started
# 104553 started
# 104555 started
# 104556 started
# 104557 started
# 104560 started
# 104561 started
# 104564 started
# 104566 started
# 104569 started
# 104570 started
# 104573 started
# 104575 started
# 104576 started
# 104579 started
# 104580 started
# 104582 started
# 104583 started
# 104584 started
# 104585 started
# 104586 started
# 104587 started
# 104588 started
# 104589 started
# 104593 started
# 104594 started
# 104595 started
# 104598 started
# 104600 started
# 104602 started
# 104603 started
# 104604 started
# 104605 started
# 104608 started
# 104609 started
# 104611 started
# 104613 started
# 104615 started
# 104616 started
# 104617 started
# 104618 started
# 104619 started
# 104621 started
# 104624 started
# 104625 started
# 104626 started
# 104628 started
# 104630 started
# 104632 started
# 104633 started
# 104634 started
# 104636 started
# 104637 started
# 104639 started
# 104640 started
# 104641 started
# 104642 started
# 104643 started
# 104644 started
# 104646 started
# 104647 started
# 104649 started
# 104650 started
# 104652 started
# 104653 started
# 104656 started
# 104658 started
# 104659 started
# 104660 started
# 104661 started
# 104665 started
# 104666 started
# 104667 started
# 104668 started
# 104672 started
# 104673 started
# 104675 started
# 104676 started
# 104677 started
# 104678 started
# 104679 started
# 104680 started
# 104681 started
# 104682 started
# 104683 started
# 104685 started
# 104686 started
# 104687 started
# 104690 started
# 104692 started
# 104694 started
# 104695 started
# 104696 started
# 104697 started
# 104698 started
# 104699 started
# 104701 started
# 104703 started
# 104704 started
# 104705 started
# 104707 started
# 104708 started
# 104710 started
# 104711 started
# 104715 started
# 104716 started
# 104717 started
# 104718 started
# 104721 started
# 104723 started
# 104724 started
# 104725 started
# 104726 started
# 104729 started
# 104730 started
# 104732 started
# 104736 started
# 104737 started
# 104739 started
# 104741 started
# 104742 started
# 104744 started
# 104745 started
# 104747 started
# 104749 started
# 104751 started
# 104752 started
# 104755 started
# 104756 started
# 104757 started
# 104758 started
# 104759 started
# 104760 started
# 104761 started
# 104762 started
# 104763 started
# 104766 started
# 104767 started
# 104768 started
# 104769 started
# 104770 started
# 104773 started
# 104774 started
# 104775 started
# 104777 started
# 104779 started
# 104783 started
# 104784 started
# 104786 started
# 104787 started
# 104788 started
# 104790 started
# 104791 started
# 104794 started
# 104795 started
# 104796 started
# 104797 started
# 104798 started
# 104799 started
# 104801 started
# 104802 started
# 104803 started
# 104805 started
# 104806 started
# 104808 started
# 104809 started
# 104810 started
# 104812 started
# 104814 started
# 104815 started
# 104816 started
# 104817 started
# 104820 started
# 104823 started
# 104824 started
# 104826 started
# 104829 started
# 104831 started
# 104833 started
# 104834 started
# 104836 started
# 104837 started
# 104840 started
# 104841 started
# 104842 started
# 104843 started
# 104845 started
# 104847 started
# 104849 started
# 104850 started
# 104852 started
# 104856 started
# 104858 started
# 104862 started
# 104863 started
# 104867 started
# 104868 started
# 104869 started
# 104870 started
# 104872 started
# 104873 started
# 104877 started
# 104878 started
# 104879 started
# 104881 started
# 104882 started
# 104883 started
# 104884 started
# 104885 started
# 104886 started
# 104888 started
# 104890 started
# 104891 started
# 104892 started
# 104893 started
# 104894 started
# 104895 started
# 104896 started
# 104897 started
# 104898 started
# 104900 started
# 104901 started
# 104903 started
# 104904 started
# 104907 started
# 104908 started
# 104910 started
# 104915 started
# 104916 started
# getting dimensions
# making array
# 104917 started
# 104918 started
# 104921 started
# 104922 started
# 104923 started
# 104924 started
# 104925 started
# 104926 started
# 104928 started
# 104929 started
# 104931 started
# 104932 started
# 104933 started
# 104935 started
# 104936 started
# 104937 started
# 104938 started
# 104939 started
# 104940 started
# 104941 started
# 104945 started
# 104946 started
# 104947 started
# 104948 started
# 104950 started
# 104951 started
# 104952 started
# 104954 started
# 104955 started
# 104956 started
# 104957 started
# 104958 started
# 104961 started
# 104964 started
# 104969 started
# 104970 started
# 104971 started
# 104972 started
# 104973 started
# 104975 started
# 104976 started
# 104979 started
# 104981 started
# 104983 started
# 104984 started
# 104985 started
# 104986 started
# 104988 started
# 104989 started
# 104994 started
# 104995 started
# 104999 started
# 105003 started
# 105006 started
# 105007 started
# 105009 started
# 105010 started
# 105011 started
# 105012 started
# 105013 started
# 105014 started
# 105016 started
# 105017 started
# 105023 started
# 105024 started
# 105027 started
# 105032 started
# 105034 started
# 105036 started
# 105037 started
# 105040 started
# 105041 started
# 105042 started
# 105047 started
# 105048 started
# 105050 started
# 105052 started
# 105054 started
# 105056 started
# 105058 started
# 105061 started
# 105062 started
# 105063 started
# 105065 started
# 105074 started
# 105075 started
# 105076 started
# 105079 started
# 105080 started
# 105082 started
# 105083 started
# 105084 started
# 105088 started
# 105090 started
# 105091 started
# 105093 started
# 105094 started
# 105098 started
# 105099 started
# 105104 started
# 105105 started
# 105106 started
# 105110 started
# 105115 started
# 105116 started
# 105117 started
# 105118 started
# 105119 started
# 105121 started
# 105123 started
# 105124 started
# 105126 started
# 105127 started
# 105131 started
# 105132 started
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-662cce23d31b> in <module>()
#       1 feature = Feature()
# ----> 2 feature.get_shards(100)
#       3
#       4 print("done")
#
# <ipython-input-5-057135961701> in get_shards(self, num_shards)
#     223         for i in np.arange(num_shards):
#     224             #generate arrays for indices
# --> 225             x,z = self.get_OH(adm_df[st_idx:st_idx+s_len],c_df,items)
#     226             #save arrays
#     227             np.save("xC"+str(i),x)
#
# <ipython-input-5-057135961701> in get_OH(self, admission_df, chartevents_df, items)
#     195
#     196             #for each row in chartevents create a row in 3D array
# --> 197             for c_idx, row in chartevents_perAdm_df.iterrows():
#     198                 ITID = row['ITEMID']
#     199                 #Generate one hot encoding for feature type.
#
# /soe/dcjenkin/workspace/venv/lib/python3.4/site-packages/pandas/core/frame.py in iterrows(self)
#     697         klass = self._constructor_sliced
#     698         for k, v in zip(self.index, self.values):
# --> 699             s = klass(v, index=columns, name=k)
#     700             yield k, s
#     701
#
# /soe/dcjenkin/workspace/venv/lib/python3.4/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     241             else:
#     242                 data = _sanitize_array(data, index, dtype, copy,
# --> 243                                        raise_cast_failure=True)
#     244
#     245                 data = SingleBlockManager(data, index, fastpath=True)
#
# /soe/dcjenkin/workspace/venv/lib/python3.4/site-packages/pandas/core/series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    2873             subarr = _sanitize_index(data, index, copy=True)
#    2874         else:
# -> 2875             subarr = _try_cast(data, True)
#    2876
#    2877         if copy:
#
# /soe/dcjenkin/workspace/venv/lib/python3.4/site-packages/pandas/core/series.py in _try_cast(arr, take_fast_path)
#    2840
#    2841         try:
# -> 2842             subarr = _possibly_cast_to_datetime(arr, dtype)
#    2843             if not is_extension_type(subarr):
#    2844                 subarr = np.array(subarr, dtype=dtype, copy=copy)
#
# KeyboardInterrupt:

# %%
# feature = Feature()
# x, z = feature.get_OH()
# import numpy as np
# np.save('xC', x)
# np.save('zC', z)
# print("done")
